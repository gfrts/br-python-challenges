# %% [markdown]
# <a href="https://colab.research.google.com/github/gfrts/br-python-challenges/blob/master/Desafio_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Desafio 1
#
# Escreva um programa em Python para contabilizar a quantidade de ocorrências de cada palavra.

# %%
palavras = [
   'red', 'green', 'black', 'pink', 'black', 'white', 'black', 'eyes',
   'white', 'black', 'orange', 'pink', 'pink', 'red', 'red', 'white', 'orange',
   'white', "black", 'pink', 'green', 'green', 'pink', 'green', 'pink',
   'white', 'orange', "orange", 'red'
]


def contabiliza_palavras(iterables):
  dic = {}
  for i in iterables:
    if i in dic:
      pass
    else:
      dic[i] = iterables.count(i)
  return dic

print(contabiliza_palavras(palavras))
# Out:
# {'red': 4, 'green': 4, 'black': 5, 'pink': 6, 'white': 5, 'eyes': 1, 'orange': 4}
